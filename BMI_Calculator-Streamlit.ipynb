# %% [markdown]
# #**<center><font color = "522258">BMI Calculator</font></center>**

# %% [markdown]
# ![Screenshot (50).png](data:image/png;base64,...)

# %%
# To install streamlit in colab
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 27.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 57.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...
#
# added 22 packages, and audited 23 packages in 2s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# 1 moderate severity vulnerability
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.

# %% [markdown]
# #**<center><font color = "8C3061">ngrok -  Tool used for exposing local servers to the internet.</font></center>**

# %%
# Command to install ngrok
# !pip install pyngrok

# %%
from pyngrok import ngrok

ngrok.set_auth_token("2m8pTgueAL7L2bjgMtIit9xdweM_78h6eEwZUbbLPN3XNuUz6")

# %%
# Write the Streamlit app code to a file-app.py
# %%writefile app.py
import streamlit as st

st.title("BMI Calculator:")
with st.form(key='BMI Calculator', clear_on_submit=False):
    col1, col2, col3 = st.columns([3, 2, 1])
    with col1:
        weight = st.number_input("Enter your weight in KGS:")
    with col2:
        height = st.number_input("Enter your height in meters:")
    with col3:
        submit = st.form_submit_button(label='Calculate')
    if submit:
        BMI = round((weight / height ** 2), 2)
        if BMI <= 18.5:
            st.error("Underweight")
        elif BMI <= 24.9:
            st.success("Healthy")
        elif BMI <= 29.9:
            st.warning("Overweight")
        else:
            st.error("OBESE")
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
public_url = ngrok.connect(8501, proto = 'http')
print(public_url)
# Out:
# NgrokTunnel: "https://49a8-104-154-73-145.ngrok-free.app" -> "http://localhost:8501"

# %% [markdown]
# #**<center><font color = "C63C51">Final Result</font></center>**

# %% [markdown]
# ![Screenshot (49).png](data:image/png;base64,...)
